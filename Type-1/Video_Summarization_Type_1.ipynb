# %%
# Check if the GPU is Detected

import torch
print(torch.cuda.is_available())
# Out:
# False

# %%
import os
import cv2
import glob
import json
import torch
import requests
import numpy as np
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms

from PIL import Image
from dotenv import load_dotenv
from google.colab import files
from transformers import BlipProcessor, BlipForConditionalGeneration, pipeline

load_dotenv()
# Out:
# True

# %%
video_path = r"input/VID.mp4"
output_dir = r"output/frames"

os.makedirs(output_dir, exist_ok=True)

vidcap = cv2.VideoCapture(video_path)
success, image = vidcap.read()
count = 0
frame_skip = 30                                 # Adjust accordingly to control frame extraction rate

while success:
    if count % frame_skip == 0:
        cv2.imwrite(os.path.join(output_dir, f"frame_{count}.jpg"), image)
    success, image = vidcap.read()
    count += 1

print(f"Extracted {len(os.listdir(output_dir))} frames to '{output_dir}'")
# Out:
# Extracted 0 frames to '/content/drive/MyDrive/Video-to-Text Summarization/frames'

# %%
# Load pretrained ResNet (remove last fully-connected layer)
resnet = models.resnet50(weights=True)              # You can use resnet18 for faster/slimmer model
resnet.eval()
feature_extractor = torch.nn.Sequential(*list(resnet.children())[:-1])

# Image preprocessing pipeline for ResNet
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225])
])

# %%
frame_files = sorted(glob.glob("/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_*.jpg"))
features = []

for path in frame_files:
    image = Image.open(path).convert("RGB")
    input_tensor = preprocess(image).unsqueeze(0)           # Add batch dimension

    with torch.no_grad():
        output = feature_extractor(input_tensor)
        vector = output.squeeze().cpu().numpy()

    features.append(vector)

features = np.array(features)
print(f"Extracted feature vectors for {len(features)} frames, vector shape: {features[0].shape}")
# Out:
# Extracted feature vectors for 200 frames, vector shape: (2048,)

# %%
class FrameImportanceLSTM(nn.Module):
    def __init__(self, input_size=2048, hidden_size=256, num_layers=2):
        super(FrameImportanceLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_size*2, 1)

    def forward(self, x):
        h, _ = self.lstm(x)
        scores = torch.sigmoid(self.fc(h)).squeeze(-1)
        return scores

# Instantiate the model
model = FrameImportanceLSTM()
model.eval()

features_tensor = torch.tensor(features).unsqueeze(0).float()
with torch.no_grad():
    importance_scores = model(features_tensor).squeeze().cpu().numpy()

# Select key frames above a threshold
import numpy as np
threshold = 0.5
key_indices = np.where(importance_scores > threshold)[0]
key_frames = [frame_files[i] for i in key_indices]
print("Selected key frames for summary:", key_frames)
# Out:
# Selected key frames for summary: ['/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_0.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1020.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1050.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1080.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1110.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1140.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1170.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_120.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1200.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1230.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1260.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1290.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1320.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1350.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1380.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1410.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1440.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1470.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_150.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1500.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1530.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1560.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1590.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1620.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1650.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1680.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1710.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1740.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1770.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_180.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1800.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1830.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1860.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1890.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1920.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1950.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_1980.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_2010.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_2040.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_2070.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_210.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_2100.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_2130.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_2160.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_2190.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_2220.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_2250.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_2280.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_2310.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_2340.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_2370.jpg', '/content/drive/MyDrive/Video-to-Text Summarization/frames/frame_240.jpg', '/content/drive/MyDriv ...

# %%
# Download pretrained BLIP model and processor
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
caption_model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# %%
def caption_frame(image_path, processor, model):
    raw_image = Image.open(image_path).convert('RGB')
    inputs = processor(raw_image, return_tensors="pt")
    with torch.no_grad():
        out = model.generate(**inputs)
        caption = processor.decode(out[0], skip_special_tokens=True)
    return caption

# Generate and print summaries
video_summary = []
for idx, frame_path in enumerate(key_frames):
    caption = caption_frame(frame_path, processor, caption_model)
    video_summary.append(f"Scene {idx+1}: {caption}")
    print(f"Scene {idx+1}: {caption}")
# Out:
# Scene 1: opening and closing of the screen
# Scene 2: a plant with a stem and leaves on it
# Scene 3: opening closing of stomata a large number of sponges in the stomata
# Scene 4: opening and closing of stomata
# Scene 5: opening and closing of smta
# Scene 6: a large green leaf with a small green leaf on it
# Scene 7: a large green leaf with a small green leaf with a small green leaf with a small green leaf with
# Scene 8: opening and closing of stomata
# Scene 9: a large, green leaf with a small leaf inside it is labeled to the center of the plant
# Scene 10: a large, long - lived cell that has been to be used for the use of the cell
# Scene 11: opening and closing of stomata
# Scene 12: opening and closing of stomata
# Scene 13: opening and closing of stomata
# Scene 14: a large, long - lived cell that has been to be used for the use of the cell
# Scene 15: opening clogi of smta a large number of smta cells in the leaf
# Scene 16: opening closing of stomata
# Scene 17: opening and closing of stomata
# Scene 18: opening and closing of stomata
# Scene 19: opening and closing of stomata
# Scene 20: opening and closing of stomata
# Scene 21: opening and closing of stomata
# Scene 22: opening and closing of stomata
# Scene 23: opening and closing of stomata
# Scene 24: a green cube with a green background and a green background
# Scene 25: a green cube with a green surface and a green surface
# Scene 26: a green cube with a green surface and a white cube with a green surface
# Scene 27: opening and closing of stomata
# Scene 28: opening and closing of stomata
# Scene 29: opening and closing of stomata
# Scene 30: a plant with a flower inside of it
# Scene 31: opening and closing of stomata
# Scene 32: a water container with a green roof and a green roof
# Scene 33: a cube with a green surface and a green surface
# Scene 34: open and closing of sta
# Scene 35: open and closing of sta
# Scene 36: open and closing of sta
# Scene 37: open and closing of sta
# Scene 38: open and closing of sta
# Scene 39: open and closing of sta
# Scene 40: open and closing of sta
# Scene 41: a plant with a flower inside of it
# Scene 42: open and closing of sta
# Scene 43: a diagram of a water cycle with the water cycle and the water cycle
# Scene 44: a diagram of a water cycle with the water cycle and the water cycle
# Scene 45: a diagram of a cell with the cell inside
# Scene 46: a diagram of a water cycle with the water cycle and the water cycle
# Scene 47: a diagram of a water cycle with the water cycle and the water cycle
# Scene 48: open and closing of stomata
# Scene 49: opening and closing of stomata stomata stomata stomata stomata st
# Scene 50: a fish is inside a tank with water inside
# Scene 51: a fish is in the water and is not moving
# Scene 52: a plant with a flower inside of it
# Scene 53: a fish is in the water and is not in the water
# Scene 54: some plants are growing in the water
# Scene 55: a plant with algaes and algaes in the water
# Scene 56: a plant with algaes and algaes in the water
# Scene 57: a plant with algaes and algaes in the water
# Scene 58: a plant with algaes and algaes in the water
# Scene 59: a plant with algaes and algaes in the water
# Scene 60: a plant with algaes and algaes in the water
# Scene 61: opening and closing of sta
# Scene 62: opening and closing of sta
# Scene 63: a plant with a flower inside of it
# Scene 64: opening and closing of sta
# Scene 65: open and closed stoma
# Scene 66: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 67: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 68: open closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 69: open closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 70: open closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 71: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 72: open closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 73: open closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 74: opening and closing of sta
# Scene 75: a plant with a flower inside of it
# Scene 76: open closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 77: open closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 78: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 79: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 80: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 81: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 82: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 83: open and closing of sta
# Scene 84: open and closing of sta
# Scene 85: open and closing of sta
# Scene 86: a person holding a camera with the words open and closing
# Scene 87: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 88: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 89: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 90: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 91: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 92: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 93: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 94: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 95: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 96: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 97: a green object with two large eyes and a black object with two smaller eyes
# Scene 98: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 99: open and closed stomata
# Scene 100: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 101: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 102: open and closed stomata
# Scene 103: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 104: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 105: open and closed cells
# Scene 106: opening and closing of stomata
# Scene 107: opening and closing of stomata
# Scene 108: a green object with a black hole in the center
# Scene 109: opening and closing of stomata
# Scene 110: opening and closing of stomata
# Scene 111: opening and closing of stomata
# Scene 112: open and closed closed cells
# Scene 113: open and closed cells
# Scene 114: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 115: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 116: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 117: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 118: open and closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed closed
# Scene 119: a diagram of a cell with a cell inside
# Scene 120: open and closed closed cells
# Scene 121: a plant with a stem and leaves growing from the ground
# Scene 122: a plant with a flower growing out of it
# Scene 123: a plant with a flower growing out of it
# Scene 124: a plant with a flower growing out of it
# Scene 125: a plant with a flower growing out of it
# Scene 126: a plant with a flower growing out of it
# Scene 127: a plant with a stem and a stem that is attached to the stem
# Scene 128: a plant with a flower growing out of it
# Scene 129: a plant with a flower growing out of it
# Scene 130: a diagram of a cell with a cell inside
# Scene 131: a plant with a flower growing out of it
# Scene 132: a plant with a flower growing out of it
# Scene 133: a plant with a flower growing out of it
# Scene 134: a plant with a flower growing out of it
# Scene 135: a plant with a flower growing out of it
# Scene 136: a plant with a flower growing out of it
# Scene 137: a plant with a flower growing out of it
# Scene 138: a plant with a flower growing out of it
# Scene 139: opening and closing of stomata since the wall guards stop snoring is thick, or other
# Scene 140: opening and closing of stomata since the wall guards stop opening is thick, often in the wall
# Scene 141: a diagram of a cell with a cell inside
# Scene 142: opening and closing of stomata since the wall guards stop opening is
# Scene 143: opening and closing of stomata since the wall guards stop opening is thick, often in the wall
# Scene 144: opening and closing of stomata since the wall guards stop snating is thick, or other
# Scene 145: opening and closing of stomata since the wall guards separate opening is thick outer conveil
# Scene 146: opening and closing of stomata since the wall guards stop s
# Scene 147: open and closing of stomata
# Scene 148: open and closing of stomata
# Scene 149: open and closing of stomata
# Scene 150: open and closing of stomata
# Scene 151: open and closing of stomata
# Scene 152: a diagram of a cell with a cell inside
# Scene 153: open and closing of stomata
# Scene 154: open and closing of stomata
# Scene 155: open and closing of stomata
# Scene 156: open and closing of stomata
# Scene 157: open and closing of stomata
# Scene 158: opening closing of stomata when the pressure of the stomata comes, the pressure of the
# Scene 159: open and closing of stomata when the pressure of the stomata comes, the pressure of
# Scene 160: opening and closing of stomata when the pressure of the stomata comes, the pressure of
# Scene 161: open and closing of sma when the pressure of the gas comes, the pressure of the gas is
# Scene 162: open and closing of sma when the pressure of the gas comes, the pressure of the gas is
# Scene 163: a diagram of a cell with a cell inside
# Scene 164: open and closing of sma when the pressure of the gas comes, the pressure of the gas is
# Scene 165: opening and closing of stoma
# Scene 166: opening and closing of stoma
# Scene 167: opening and closing of stoma
# Scene 168: opening and closing of stoma
# Scene 169: opening and closing of stoma
# Scene 170: opening and closing of stomata
# Scene 171: opening and closing of stomata
# Scene 172: opening and closing of stomata
# Scene 173: opening and closing of stomata
# Scene 174: opening and closing of stomata
# Scene 175: opening and closing of stomata
# Scene 176: opening and closing of stoma
# Scene 177: opening and closing of stoma
# Scene 178: opening and closing of stoma
# Scene 179: opening and closing of stoma
# Scene 180: opening and closing of stoma
# Scene 181: opening and closing of stoma
# Scene 182: opening and closing of stoma
# Scene 183: opening and closing of stoma
# Scene 184: opening and closing of stoma
# Scene 185: opening and closing of sta
# Scene 186: opening and closing of stomata
# Scene 187: opening and closing of stomata
# Scene 188: opening and closing of stomata
# Scene 189: opening and closing of stomata
# Scene 190: opening and closing of stomata
# Scene 191: opening and closing of stomata
# Scene 192: a flower is growing out of the ground
# Scene 193: a flower is growing out of the ground
# Scene 194: a flower is growing out of the ground
# Scene 195: a plant with roots and roots, with the roots exposed
# Scene 196: opening and closing of sta
# Scene 197: a plant with leaves growing out of it
# Scene 198: a plant with water inside and a leaf inside
# Scene 199: a plant with a stem and leaves on it
# Scene 200: a plant with a stem and leaves on it

# %%
with open("/content/drive/MyDrive/Video-to-Text Summarization/video_summary.txt", "w") as f:
    for line in video_summary:
        f.write(line + "\n")

# %%
summarizer = pipeline("summarization", model="t5-small")
# Out:
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
f = open("/content/drive/MyDrive/Video-to-Text Summarization/video_summary.txt", "r")
summary_raw = f.read()

response = requests.post(
    os.getenv(("API_URL")),
    headers = {
        "Authorization":f"Bearer {os.getenv("API_KEY")}",
    },
    data = json.dumps({
        "model":"tngtech/deepseek-r1t2-chimera:free",
        "messages":[{
            "role":"user",
            "content": f'''
            Rewrite and summarize this scientific video breakdown for a general audience. Only give the summary, no other intro or outro.:

            {summary_raw}''',
      }]
    })
)

print(response.json())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 f = open("/content/drive/MyDrive/Video-to-Text Summarization/video_summary.txt", "r")
#       2 summary_raw = f.read()
#       4 api_url = "https://openrouter.ai/api/v1/chat/completions"
#
# File D:\Codings\Video-to-Text-Summarization\.venv\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Video-to-Text Summarization/video_summary.txt'

# %%
print(response.json()['choices'][0]['message']['content'])
# Out:
# AI summary:
#
# This video explains how plants regulate gas exchange and water through tiny leaf pores called stomata. Stomata continually open and close, controlled by surrounding guard cells which swell or shrink due to water pressure changes. When guard cells fill with water, the stomata open, allowing carbon dioxide in for photosynthesis while releasing oxygen and water vapor. The thick-walled guard cells prevent collapse, ensuring efficient operation. The process connects to larger plant functions, including growth, water circulation, and adaptations in both land and aquatic plants. Repeated visuals of stomata, guard cells, and diagrams emphasize this dynamic balance critical to plant survival.
